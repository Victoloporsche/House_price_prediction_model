# %%
import pandas as pd
import numpy as np
from main import Main
import warnings
import pickle
warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#train and test data
train_data = pd.read_csv('../input/train.csv')
test_data = pd.read_csv('../input/test.csv')

# %%
house_price_main_model = Main(train =train_data, test=test_data, id_column='Id', y_column_name= 'SalePrice', 
                              num_of_features_to_select=80)

# %%
features_with_na = house_price_main_model.check_missing_values()

# %%
numerical_features = house_price_main_model.check_numerical_features()

# %%
categorical_features = house_price_main_model.check_categorical_features()

# %%
mean_cross_validation_score_rf_regressor = house_price_main_model.cross_validation_random_forest_regressor()

# %%
mean_cross_validation_score_xgb_regressor = house_price_main_model.cross_validation_random_extra_tree_regressor()

# %%
mean_cross_validation_score_extra_tree_regressor = house_price_main_model.cross_validation_random_xgb_regressor()

# %%
ytest, model = house_price_main_model.optimize_and_train_model(predicted_column_name= 'Predicted_Sale_Price')

# %%
pickle.dump(model, open('../models/model_house_price_predictor.pkl','wb'))

# %%
train_with_pytorch = house_price_main_model.train_with_pytorch()
# Out:
# Epoch number 1 and the loss is 197583.671875
# Epoch number 11 and the loss is 197580.359375
# Epoch number 21 and the loss is 197560.09375
# Epoch number 31 and the loss is 197493.703125
# Epoch number 41 and the loss is 197332.65625
# Epoch number 51 and the loss is 197008.265625
# Epoch number 61 and the loss is 196433.65625
# Epoch number 71 and the loss is 195507.234375
# Epoch number 81 and the loss is 194116.765625
# Epoch number 91 and the loss is 192142.875
# Epoch number 101 and the loss is 189463.03125
# Epoch number 111 and the loss is 185954.765625
# Epoch number 121 and the loss is 181499.734375
# Epoch number 131 and the loss is 175988.171875
# Epoch number 141 and the loss is 169325.28125
# Epoch number 151 and the loss is 161440.34375
# Epoch number 161 and the loss is 152301.203125
# Epoch number 171 and the loss is 141938.15625
# Epoch number 181 and the loss is 130484.4609375
# Epoch number 191 and the loss is 118244.8515625
# Epoch number 201 and the loss is 105804.4296875
# Epoch number 211 and the loss is 94160.5078125
# Epoch number 221 and the loss is 84718.953125
# Epoch number 231 and the loss is 78726.0703125
# Epoch number 241 and the loss is 76093.765625
# Epoch number 251 and the loss is 75275.2265625
# Epoch number 261 and the loss is 74861.1640625
# Epoch number 271 and the loss is 74409.1953125
# Epoch number 281 and the loss is 73940.84375
# Epoch number 291 and the loss is 73492.1171875
# Epoch number 301 and the loss is 73056.03125
# Epoch number 311 and the loss is 72622.7734375
# Epoch number 321 and the loss is 72190.109375
# Epoch number 331 and the loss is 71758.09375
# Epoch number 341 and the loss is 71326.4140625
# Epoch number 351 and the loss is 70894.53125
# Epoch number 361 and the loss is 70461.9765625
# Epoch number 371 and the loss is 70028.3828125
# Epoch number 381 and the loss is 69593.3828125
# Epoch number 391 and the loss is 69156.640625
# Epoch number 401 and the loss is 68717.8203125
# Epoch number 411 and the loss is 68276.6171875
# Epoch number 421 and the loss is 67832.734375
# Epoch number 431 and the loss is 67385.84375
# Epoch number 441 and the loss is 66935.640625
# Epoch number 451 and the loss is 66481.8515625
# Epoch number 461 and the loss is 66024.1328125
# Epoch number 471 and the loss is 65562.203125
# Epoch number 481 and the loss is 65095.73828125
# Epoch number 491 and the loss is 64624.4375
# Epoch number 501 and the loss is 64147.98828125
# Epoch number 511 and the loss is 63666.05859375
# Epoch number 521 and the loss is 63178.3359375
# Epoch number 531 and the loss is 62684.5078125
# Epoch number 541 and the loss is 62184.24609375
# Epoch number 551 and the loss is 61677.2265625
# Epoch number 561 and the loss is 61163.140625
# Epoch number 571 and the loss is 60641.66796875
# Epoch number 581 and the loss is 60112.51171875
# Epoch number 591 and the loss is 59575.37890625
# Epoch number 601 and the loss is 59029.9921875
# Epoch number 611 and the loss is 58476.109375
# Epoch number 621 and the loss is 57913.50390625
# Epoch number 631 and the loss is 57341.984375
# Epoch number 641 and the loss is 56761.421875
# Epoch number 651 and the loss is 56171.7265625
# Epoch number 661 and the loss is 55572.8984375
# Epoch number 671 and the loss is 54965.00390625
# Epoch number 681 and the loss is 54348.22265625
# Epoch number 691 and the loss is 53722.84765625
# Epoch number 701 and the loss is 53089.32421875
# Epoch number 711 and the loss is 52448.26171875
# Epoch number 721 and the loss is 51800.4375
# Epoch number 731 and the loss is 51146.87109375
# Epoch number 741 and the loss is 50488.80078125
# Epoch number 751 and the loss is 49827.7421875
# Epoch number 761 and the loss is 49165.4765625
# Epoch number 771 and the loss is 48504.08984375
# Epoch number 781 and the loss is 47845.984375
# Epoch number 791 and the loss is 47193.82421875
# Epoch number 801 and the loss is 46550.5546875
# Epoch number 811 and the loss is 45919.3515625
# Epoch number 821 and the loss is 45303.53125
# Epoch number 831 and the loss is 44706.4921875
# Epoch number 841 and the loss is 44131.5546875
# Epoch number 851 and the loss is 43581.875
# Epoch number 861 and the loss is 43060.2734375
# Epoch number 871 and the loss is 42569.08203125
# Epoch number 881 and the loss is 42110.05859375
# Epoch number 891 and the loss is 41684.2265625
# Epoch number 901 and the loss is 41291.859375
# Epoch number 911 and the loss is 40932.453125
# Epoch number 921 and the loss is 40604.7890625
# Epoch number 931 and the loss is 40307.02734375
# Epoch number 941 and the loss is 40036.83203125
# Epoch number 951 and the loss is 39791.5234375
# Epoch number 961 and the loss is 39568.2734375
# Epoch number 971 and the loss is 39364.2265625
# Epoch number 981 and the loss is 39176.62890625
# Epoch number 991 and the loss is 39002.9375
# Epoch number 1001 and the loss is 38840.8671875
# Epoch number 1011 and the loss is 38688.43359375
# Epoch number 1021 and the loss is 38543.95703125
# Epoch number 1031 and the loss is 38406.04296875
# Epoch number 1041 and the loss is 38273.55859375
# Epoch number 1051 and the loss is 38145.59765625
# Epoch number 1061 and the loss is 38021.453125
# Epoch number 1071 and the loss is 37900.578125
# Epoch number 1081 and the loss is 37782.55078125
# Epoch number 1091 and the loss is 37667.0546875
# Epoch number 1101 and the loss is 37553.83984375
# Epoch number 1111 and the loss is 37442.73828125
# Epoch number 1121 and the loss is 37333.6015625
# Epoch number 1131 and the loss is 37226.33984375
# Epoch number 1141 and the loss is 37120.87109375
# Epoch number 1151 and the loss is 37017.140625
# Epoch number 1161 and the loss is 36915.1015625
# Epoch number 1171 and the loss is 36814.71875
# Epoch number 1181 and the loss is 36715.9609375
# Epoch number 1191 and the loss is 36618.8125
# Epoch number 1201 and the loss is 36523.25
# Epoch number 1211 and the loss is 36429.2578125
# Epoch number 1221 and the loss is 36336.8203125
# Epoch number 1231 and the loss is 36245.92578125
# Epoch number 1241 and the loss is 36156.55859375
# Epoch number 1251 and the loss is 36068.7109375
# Epoch number 1261 and the loss is 35982.37109375
# Epoch number 1271 and the loss is 35897.53125
# Epoch number 1281 and the loss is 35814.171875
# Epoch number 1291 and the loss is 35732.2890625
# Epoch number 1301 and the loss is 35651.87109375
# Epoch number 1311 and the loss is 35572.90234375
# Epoch number 1321 and the loss is 35495.375
# Epoch number 1331 and the loss is 35419.2734375
# Epoch number 1341 and the loss is 35344.5859375
# Epoch number 1351 and the loss is 35271.30078125
# Epoch number 1361 and the loss is 35199.41015625
# Epoch number 1371 and the loss is 35128.90234375
# Epoch number 1381 and the loss is 35059.75
# Epoch number 1391 and the loss is 34991.9453125
# Epoch number 1401 and the loss is 34925.48046875
# Epoch number 1411 and the loss is 34860.328125
# Epoch number 1421 and the loss is 34796.484375
# Epoch number 1431 and the loss is 34733.921875
# Epoch number 1441 and the loss is 34672.63671875
# Epoch number 1451 and the loss is 34612.609375
# Epoch number 1461 and the loss is 34553.8203125
# Epoch number 1471 and the loss is 34496.25
# Epoch number 1481 and the loss is 34439.8828125
# Epoch number 1491 and the loss is 34384.69921875
# Epoch number 1501 and the loss is 34330.68359375
# Epoch number 1511 and the loss is 34277.8203125
# Epoch number 1521 and the loss is 34226.08203125
# Epoch number 1531 and the loss is 34175.45703125
# Epoch number 1541 and the loss is 34125.92578125
# Epoch number 1551 and the loss is 34077.45703125
# Epoch number 1561 and the loss is 34030.04296875
# Epoch number 1571 and the loss is 33983.66015625
# Epoch number 1581 and the loss is 33938.2890625
# Epoch number 1591 and the loss is 33893.90625
# Epoch number 1601 and the loss is 33850.5
# Epoch number 1611 and the loss is 33808.0390625
# Epoch number 1621 and the loss is 33766.5078125
# Epoch number 1631 and the loss is 33725.88671875
# Epoch number 1641 and the loss is 33686.15234375
# Epoch number 1651 and the loss is 33647.28515625
# Epoch number 1661 and the loss is 33609.265625
# Epoch number 1671 and the loss is 33572.0703125
# Epoch number 1681 and the loss is 33535.6875
# Epoch number 1691 and the loss is 33500.0859375
# Epoch number 1701 and the loss is 33465.24609375
# Epoch number 1711 and the loss is 33431.15625
# Epoch number 1721 and the loss is 33397.79296875
# Epoch number 1731 and the loss is 33365.13671875
# Epoch number 1741 and the loss is 33333.1640625
# Epoch number 1751 and the loss is 33301.86328125
# Epoch number 1761 and the loss is 33271.2109375
# Epoch number 1771 and the loss is 33241.19140625
# Epoch number 1781 and the loss is 33211.77734375
# Epoch number 1791 and the loss is 33182.96484375
# Epoch number 1801 and the loss is 33154.7265625
# Epoch number 1811 and the loss is 33127.05859375
# Epoch number 1821 and the loss is 33099.921875
# Epoch number 1831 and the loss is 33073.31640625
# Epoch number 1841 and the loss is 33047.21875
# Epoch number 1851 and the loss is 33021.62109375
# Epoch number 1861 and the loss is 32996.5
# Epoch number 1871 and the loss is 32971.84375
# Epoch number 1881 and the loss is 32947.640625
# Epoch number 1891 and the loss is 32923.875
# Epoch number 1901 and the loss is 32900.53125
# Epoch number 1911 and the loss is 32877.59765625
# Epoch number 1921 and the loss is 32855.05859375
# Epoch number 1931 and the loss is 32832.90625
# Epoch number 1941 and the loss is 32811.125
# Epoch number 1951 and the loss is 32789.70703125
# Epoch number 1961 and the loss is 32768.62890625
# Epoch number 1971 and the loss is 32747.896484375
# Epoch number 1981 and the loss is 32727.482421875
# Epoch number 1991 and the loss is 32707.39453125
# Epoch number 2001 and the loss is 32687.61328125
# Epoch number 2011 and the loss is 32668.130859375
# Epoch number 2021 and the loss is 32648.93359375
# Epoch number 2031 and the loss is 32630.01953125
# Epoch number 2041 and the loss is 32611.376953125
# Epoch number 2051 and the loss is 32592.99609375
# Epoch number 2061 and the loss is 32574.87890625
# Epoch number 2071 and the loss is 32557.0
# Epoch number 2081 and the loss is 32539.369140625
# Epoch number 2091 and the loss is 32521.970703125
# Epoch number 2101 and the loss is 32504.798828125
# Epoch number 2111 and the loss is 32487.8515625
# Epoch number 2121 and the loss is 32471.1171875
# Epoch number 2131 and the loss is 32454.59375
# Epoch number 2141 and the loss is 32438.2734375
# Epoch number 2151 and the loss is 32422.15625
# Epoch number 2161 and the loss is 32406.228515625
# Epoch number 2171 and the loss is 32390.49609375
# Epoch number 2181 and the loss is 32374.9453125
# Epoch number 2191 and the loss is 32359.5703125
# Epoch number 2201 and the loss is 32344.37890625
# Epoch number 2211 and the loss is 32329.35546875
# Epoch number 2221 and the loss is 32314.498046875
# Epoch number 2231 and the loss is 32299.810546875
# Epoch number 2241 and the loss is 32285.28125
# Epoch number 2251 and the loss is 32270.908203125
# Epoch number 2261 and the loss is 32256.685546875
# Epoch number 2271 and the loss is 32242.6171875
# Epoch number 2281 and the loss is 32228.6953125
# Epoch number 2291 and the loss is 32214.921875
# Epoch number 2301 and the loss is 32201.2890625
# Epoch number 2311 and the loss is 32187.798828125
# Epoch number 2321 and the loss is 32174.447265625
# Epoch number 2331 and the loss is 32161.224609375
# Epoch number 2341 and the loss is 32148.140625
# Epoch number 2351 and the loss is 32135.185546875
# Epoch number 2361 and the loss is 32122.357421875
# Epoch number 2371 and the loss is 32109.658203125
# Epoch number 2381 and the loss is 32097.08203125
# Epoch number 2391 and the loss is 32084.626953125
# Epoch number 2401 and the loss is 32072.296875
# Epoch number 2411 and the loss is 32060.078125
# Epoch number 2421 and the loss is 32047.984375
# Epoch number 2431 and the loss is 32036.0
# Epoch number 2441 and the loss is 32024.134765625
# Epoch number 2451 and the loss is 32012.3828125
# Epoch number 2461 and the loss is 32000.740234375
# Epoch number 2471 and the loss is 31989.208984375
# Epoch number 2481 and the loss is 31977.78515625
# Epoch number 2491 and the loss is 31966.46875
# Epoch number 2501 and the loss is 31955.26171875
# Epoch number 2511 and the loss is 31944.154296875
# Epoch number 2521 and the loss is 31933.15625
# Epoch number 2531 and the loss is 31922.259765625
# Epoch number 2541 and the loss is 31911.4609375
# Epoch number 2551 and the loss is 31900.765625
# Epoch number 2561 and the loss is 31890.171875
# Epoch number 2571 and the loss is 31879.671875
# Epoch number 2581 and the loss is 31869.275390625
# Epoch number 2591 and the loss is 31858.97265625
# Epoch number 2601 and the loss is 31848.767578125
# Epoch number 2611 and the loss is 31838.650390625
# Epoch number 2621 and the loss is 31828.634765625
# Epoch number 2631 and the loss is 31818.7109375
# Epoch number 2641 and the loss is 31808.87890625
# Epoch number 2651 and the loss is 31799.142578125
# Epoch number 2661 and the loss is 31789.4921875
# Epoch number 2671 and the loss is 31779.93359375
# Epoch number 2681 and the loss is 31770.462890625
# Epoch number 2691 and the loss is 31761.080078125
# Epoch number 2701 and the loss is 31751.787109375
# Epoch number 2711 and the loss is 31742.587890625
# Epoch number 2721 and the loss is 31733.46875
# Epoch number 2731 and the loss is 31724.439453125
# Epoch number 2741 and the loss is 31715.494140625
# Epoch number 2751 and the loss is 31706.6328125
# Epoch number 2761 and the loss is 31697.857421875
# Epoch number 2771 and the loss is 31689.166015625
# Epoch number 2781 and the loss is 31680.5546875
# Epoch number 2791 and the loss is 31672.029296875
# Epoch number 2801 and the loss is 31663.5859375
# Epoch number 2811 and the loss is 31655.2265625
# Epoch number 2821 and the loss is 31646.94140625
# Epoch number 2831 and the loss is 31638.7421875
# Epoch number 2841 and the loss is 31630.623046875
# Epoch number 2851 and the loss is 31622.580078125
# Epoch number 2861 and the loss is 31614.6171875
# Epoch number 2871 and the loss is 31606.73828125
# Epoch number 2881 and the loss is 31598.93359375
# Epoch number 2891 and the loss is 31591.20703125
# Epoch number 2901 and the loss is 31583.556640625
# Epoch number 2911 and the loss is 31575.98046875
# Epoch number 2921 and the loss is 31568.482421875
# Epoch number 2931 and the loss is 31561.060546875
# Epoch number 2941 and the loss is 31553.71484375
# Epoch number 2951 and the loss is 31546.443359375
# Epoch number 2961 and the loss is 31539.244140625
# Epoch number 2971 and the loss is 31532.123046875
# Epoch number 2981 and the loss is 31525.0703125
# Epoch number 2991 and the loss is 31518.087890625
# Epoch number 3001 and the loss is 31511.1875
# Epoch number 3011 and the loss is 31504.35546875
# Epoch number 3021 and the loss is 31497.591796875
# Epoch number 3031 and the loss is 31490.900390625
# Epoch number 3041 and the loss is 31484.279296875
# Epoch number 3051 and the loss is 31477.73046875
# Epoch number 3061 and the loss is 31471.248046875
# Epoch number 3071 and the loss is 31464.8359375
# Epoch number 3081 and the loss is 31458.494140625
# Epoch number 3091 and the loss is 31452.220703125
# Epoch number 3101 and the loss is 31446.017578125
# Epoch number 3111 and the loss is 31439.873046875
# Epoch number 3121 and the loss is 31433.80078125
# Epoch number 3131 and the loss is 31427.791015625
# Epoch number 3141 and the loss is 31421.849609375
# Epoch number 3151 and the loss is 31415.974609375
# Epoch number 3161 and the loss is 31410.169921875
# Epoch number 3171 and the loss is 31404.41796875
# Epoch number 3181 and the loss is 31398.736328125
# Epoch number 3191 and the loss is 31393.119140625
# Epoch number 3201 and the loss is 31387.55859375
# Epoch number 3211 and the loss is 31382.064453125
# Epoch number 3221 and the loss is 31376.634765625
# Epoch number 3231 and the loss is 31371.263671875
# Epoch number 3241 and the loss is 31365.951171875
# Epoch number 3251 and the loss is 31360.705078125
# Epoch number 3261 and the loss is 31355.51171875
# Epoch number 3271 and the loss is 31350.376953125
# Epoch number 3281 and the loss is 31345.306640625
# Epoch number 3291 and the loss is 31340.294921875
# Epoch number 3301 and the loss is 31335.3359375
# Epoch number 3311 and the loss is 31330.4375
# Epoch number 3321 and the loss is 31325.59375
# Epoch number 3331 and the loss is 31320.806640625
# Epoch number 3341 and the loss is 31316.078125
# Epoch number 3351 and the loss is 31311.400390625
# Epoch number 3361 and the loss is 31306.779296875
# Epoch number 3371 and the loss is 31302.212890625
# Epoch number 3381 and the loss is 31297.697265625
# Epoch number 3391 and the loss is 31293.23046875
# Epoch number 3401 and the loss is 31288.82421875
# Epoch number 3411 and the loss is 31284.466796875
# Epoch number 3421 and the loss is 31280.158203125
# Epoch number 3431 and the loss is 31275.8984375
# Epoch number 3441 and the loss is 31271.693359375
# Epoch number 3451 and the loss is 31267.541015625
# Epoch number 3461 and the loss is 31263.431640625
# Epoch number 3471 and the loss is 31259.37109375
# Epoch number 3481 and the loss is 31255.35546875
# Epoch number 3491 and the loss is 31251.392578125
# Epoch number 3501 and the loss is 31247.478515625
# Epoch number 3511 and the loss is 31243.603515625
# Epoch number 3521 and the loss is 31239.77734375
# Epoch number 3531 and the loss is 31236.0
# Epoch number 3541 and the loss is 31232.2578125
# Epoch number 3551 and the loss is 31228.5703125
# Epoch number 3561 and the loss is 31224.919921875
# Epoch number 3571 and the loss is 31221.310546875
# Epoch number 3581 and the loss is 31217.75
# Epoch number 3591 and the loss is 31214.2265625
# Epoch number 3601 and the loss is 31210.744140625
# Epoch number 3611 and the loss is 31207.306640625
# Epoch number 3621 and the loss is 31203.91015625
# Epoch number 3631 and the loss is 31200.544921875
# Epoch number 3641 and the loss is 31197.23046875
# Epoch number 3651 and the loss is 31193.9453125
# Epoch number 3661 and the loss is 31190.705078125
# Epoch number 3671 and the loss is 31187.49609375
# Epoch number 3681 and the loss is 31184.322265625
# Epoch number 3691 and the loss is 31181.193359375
# Epoch number 3701 and the loss is 31178.095703125
# Epoch number 3711 and the loss is 31175.03515625
# Epoch number 3721 and the loss is 31172.009765625
# Epoch number 3731 and the loss is 31169.017578125
# Epoch number 3741 and the loss is 31166.064453125
# Epoch number 3751 and the loss is 31163.138671875
# Epoch number 3761 and the loss is 31160.25
# Epoch number 3771 and the loss is 31157.390625
# Epoch number 3781 and the loss is 31154.568359375
# Epoch number 3791 and the loss is 31151.77734375
# Epoch number 3801 and the loss is 31149.017578125
# Epoch number 3811 and the loss is 31146.283203125
# Epoch number 3821 and the loss is 31143.583984375
# Epoch number 3831 and the loss is 31140.9140625
# Epoch number 3841 and the loss is 31138.271484375
# Epoch number 3851 and the loss is 31135.66015625
# Epoch number 3861 and the loss is 31133.078125
# Epoch number 3871 and the loss is 31130.5234375
# Epoch number 3881 and the loss is 31127.998046875
# Epoch number 3891 and the loss is 31125.498046875
# Epoch number 3901 and the loss is 31123.025390625
# Epoch number 3911 and the loss is 31120.580078125
# Epoch number 3921 and the loss is 31118.16015625
# Epoch number 3931 and the loss is 31115.765625
# Epoch number 3941 and the loss is 31113.396484375
# Epoch number 3951 and the loss is 31111.060546875
# Epoch number 3961 and the loss is 31108.7421875
# Epoch number 3971 and the loss is 31106.453125
# Epoch number 3981 and the loss is 31104.181640625
# Epoch number 3991 and the loss is 31101.93359375
# Epoch number 4001 and the loss is 31099.708984375
# Epoch number 4011 and the loss is 31097.5078125
# Epoch number 4021 and the loss is 31095.3359375
# Epoch number 4031 and the loss is 31093.181640625
# Epoch number 4041 and the loss is 31091.048828125
# Epoch number 4051 and the loss is 31088.939453125
# Epoch number 4061 and the loss is 31086.849609375
# Epoch number 4071 and the loss is 31084.78125
# Epoch number 4081 and the loss is 31082.734375
# Epoch number 4091 and the loss is 31080.70703125
# Epoch number 4101 and the loss is 31078.69921875
# Epoch number 4111 and the loss is 31076.712890625
# Epoch number 4121 and the loss is 31074.74609375
# Epoch number 4131 and the loss is 31072.796875
# Epoch number 4141 and the loss is 31070.8671875
# Epoch number 4151 and the loss is 31068.953125
# Epoch number 4161 and the loss is 31067.060546875
# Epoch number 4171 and the loss is 31065.185546875
# Epoch number 4181 and the loss is 31063.328125
# Epoch number 4191 and the loss is 31061.494140625
# Epoch number 4201 and the loss is 31059.669921875
# Epoch number 4211 and the loss is 31057.865234375
# Epoch number 4221 and the loss is 31056.078125
# Epoch number 4231 and the loss is 31054.3046875
# Epoch number 4241 and the loss is 31052.548828125
# Epoch number 4251 and the loss is 31050.80859375
# Epoch number 4261 and the loss is 31049.08984375
# Epoch number 4271 and the loss is 31047.3828125
# Epoch number 4281 and the loss is 31045.6875
# Epoch number 4291 and the loss is 31044.01171875
# Epoch number 4301 and the loss is 31042.349609375
# Epoch number 4311 and the loss is 31040.69921875
# Epoch number 4321 and the loss is 31039.06640625
# Epoch number 4331 and the loss is 31037.4453125
# Epoch number 4341 and the loss is 31035.84375
# Epoch number 4351 and the loss is 31034.251953125
# Epoch number 4361 and the loss is 31032.67578125
# Epoch number 4371 and the loss is 31031.11328125
# Epoch number 4381 and the loss is 31029.560546875
# Epoch number 4391 and the loss is 31028.025390625
# Epoch number 4401 and the loss is 31026.5
# Epoch number 4411 and the loss is 31024.986328125
# Epoch number 4421 and the loss is 31023.48828125
# Epoch number 4431 and the loss is 31022.0
# Epoch number 4441 and the loss is 31020.53125
# Epoch number 4451 and the loss is 31019.06640625
# Epoch number 4461 and the loss is 31017.615234375
# Epoch number 4471 and the loss is 31016.173828125
# Epoch number 4481 and the loss is 31014.74609375
# Epoch number 4491 and the loss is 31013.330078125
# Epoch number 4501 and the loss is 31011.92578125
# Epoch number 4511 and the loss is 31010.533203125
# Epoch number 4521 and the loss is 31009.1484375
# Epoch number 4531 and the loss is 31007.775390625
# Epoch number 4541 and the loss is 31006.4140625
# Epoch number 4551 and the loss is 31005.0625
# Epoch number 4561 and the loss is 31003.71875
# Epoch number 4571 and the loss is 31002.390625
# Epoch number 4581 and the loss is 31001.0703125
# Epoch number 4591 and the loss is 30999.7578125
# Epoch number 4601 and the loss is 30998.45703125
# Epoch number 4611 and the loss is 30997.162109375
# Epoch number 4621 and the loss is 30995.880859375
# Epoch number 4631 and the loss is 30994.607421875
# Epoch number 4641 and the loss is 30993.345703125
# Epoch number 4651 and the loss is 30992.08984375
# Epoch number 4661 and the loss is 30990.841796875
# Epoch number 4671 and the loss is 30989.6015625
# Epoch number 4681 and the loss is 30988.373046875
# Epoch number 4691 and the loss is 30987.150390625
# Epoch number 4701 and the loss is 30985.935546875
# Epoch number 4711 and the loss is 30984.734375
# Epoch number 4721 and the loss is 30983.5390625
# Epoch number 4731 and the loss is 30982.357421875
# Epoch number 4741 and the loss is 30981.173828125
# Epoch number 4751 and the loss is 30980.0
# Epoch number 4761 and the loss is 30978.833984375
# Epoch number 4771 and the loss is 30977.67578125
# Epoch number 4781 and the loss is 30976.529296875
# Epoch number 4791 and the loss is 30975.38671875
# Epoch number 4801 and the loss is 30974.251953125
# Epoch number 4811 and the loss is 30973.125
# Epoch number 4821 and the loss is 30972.005859375
# Epoch number 4831 and the loss is 30970.89453125
# Epoch number 4841 and the loss is 30969.78515625
# Epoch number 4851 and the loss is 30968.68359375
# Epoch number 4861 and the loss is 30967.58984375
# Epoch number 4871 and the loss is 30966.50390625
# Epoch number 4881 and the loss is 30965.419921875
# Epoch number 4891 and the loss is 30964.345703125
# Epoch number 4901 and the loss is 30963.27734375
# Epoch number 4911 and the loss is 30962.21484375
# Epoch number 4921 and the loss is 30961.162109375
# Epoch number 4931 and the loss is 30960.109375
# Epoch number 4941 and the loss is 30959.0703125
# Epoch number 4951 and the loss is 30958.03125
# Epoch number 4961 and the loss is 30957.0
# Epoch number 4971 and the loss is 30955.97265625
# Epoch number 4981 and the loss is 30954.953125
# Epoch number 4991 and the loss is 30953.94140625

# %%
y_predcition = house_price_main_model.prediction_pytorch()

# %%
y_predcition
# Out:
#         Id      SalePrice
# 0     1461   99589.734375
# 1     1462  168195.656250
# 2     1463  166253.250000
# 3     1464  189116.000000
# 4     1465  189134.546875
# ...    ...            ...
# 1454  2915   67163.179688
# 1455  2916   56250.960938
# 1456  2917  150296.750000
# 1457  2918  121517.695312
# 1458  2919  249490.500000
#
# [1459 rows x 2 columns]
